# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xp=np.array([0,6])
yp=np.array([0,50])
plt.plot(xp,yp)
plt.show()

# %%
xp=np.array([5,6])
yp=np.array([1,40])
plt.plot(xp,yp,'o')
plt.show()

# %%
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
print(x,y)
plt.plot(x,y)
plt.show()
# Out:
# [1 2 6 8] [ 3  8  1 10]

# %%
y=np.array([3,8,1,10])
plt.plot(y,marker='H')
plt.show()

# %%
y=np.array([3,8,1,10])
plt.plot(y,'o:r')
plt.show()

# %%
x=[10,20,30,40]
y=[50,60,70,80]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid()
plt.show()

# %%
plt.plot([1,2,3,4])
plt.plot([10,20,30,40])
plt.plot([1,2,3,4,5],[10,20,30,40,50])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
a=[1,2,3,4]
b=[i**2 for i in a]
print(a)
print(b)
plt.plot(a,b)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
# Out:
# [1, 2, 3, 4]
# [1, 4, 9, 16]

# %%
x=[10,20,30,40]
plt.plot(x,x,'ro')
plt.ylabel('y-axis')
plt.xlabel('x-axis')
plt.xlim(0,30)
plt.ylim(0,30)
plt.plot(x)
plt.grid(True)
plt.show()

# %%
t1=np.arange(5)
plt.plot(t1,'r--',t1**4,'bs',t1**3,'g^',t1**5,'ro')
plt.show()

# %%
x=[1,2,3,4]
plt.plot(x,[elem for elem in x],label='linear')
plt.plot(x,[elem**2 for elem in x],label='square')
plt.grid(True)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.savefig('myimg.png')
plt.show()

# %%
#Histogram
data=np.random.randn(8,8)
plt.hist(data)
plt.show()

# %%
x=[10,20,30]
plt.hist(x)
plt.show()

# %%
#Bar chart

# %%
my_dict={'A':30,'B':65,'C':50,'D':80}
for i,key in my_dict.items():
    print(i,key)
    plt.bar(i,key)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
# Out:
# A 30
# B 65
# C 50
# D 80

# %%
x=[6000,20000,3000,70000,30000]
my_label=['DMK','Cars','Super-cars','bicycle','planes']
plt.pie(x,labels=my_label)
plt.show()

# %%
#Scatter plot
x=np.random.rand(100)
y=np.random.rand(100)
plt.scatter(x,y)
plt.show()
