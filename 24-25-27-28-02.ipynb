# %%
#functions
def function1():#function defination
    print("Welcome to the function")
function1()#function calling
# Out:
# Welcome to the function

# %%
def fun1():
    p1=input("Enter the p1 value is::")
    print("Your p1 value is::",p1)
def fun2():
    p2=input("Enter the p2 value is::")
    print("Your p2 value is::",p2)
fun1()
fun2()
# Out:
# Enter the p1 value is::100
# Your p1 value is:: 100
# Enter the p2 value is::200
# Your p2 value is:: 200

# %%
def addProduct(pid,pname="apple"):#default arguments
    print("Your value is::",pid,pname)
def addCategory(cid,cname):
    print("Your value is::",cid,cname)
def custProcess():#empty function
    pass
addProduct(1001)
addCategory(2001,'mobile')
# Out:
# Your value is:: 1001 apple
# Your value is:: 2001 mobile

# %%
def looping():
    for i in range(5):
        print("I value is::",i)
looping()
# Out:
# I value is:: 0
# I value is:: 1
# I value is:: 2
# I value is:: 3
# I value is:: 4

# %%
#ListExample
list1=[10,20,30,40]
print(list1)
print(type(list1))
# Out:
# [10, 20, 30, 40]
# <class 'list'>

# %%
list2=[100,"Azar",'a',2.5]
print(list2)
print(type(list2))
# Out:
# [100, 'Azar', 'a', 2.5]
# <class 'list'>

# %%
list2[0:3]
# Out:
# [100, 'Azar', 'a']

# %%
list2[-3:-1]
# Out:
# ['Azar', 'a']

# %%
list2[::2]
# Out:
# [100, 'a']

# %%
name=["azar","azar","mohamed","sheik"]
print(name)
print(type(name))
# Out:
# ['azar', 'azar', 'mohamed', 'sheik']
# <class 'list'>

# %%
list1
# Out:
# [10, 20, 30, 40]

# %%
list1[0]=100
list1
# Out:
# [100, 20, 30, 40]

# %%
list1
# Out:
# [100, 20, 30, 40]

# %%
if 110 in list1:
    print("It found")
else:
    print("It not found")
# Out:
# It not found

# %%
name
# Out:
# ['azar', 'azar', 'mohamed', 'sheik']

# %%
if "raja" in name:
    print("Its is found")
else:
    print("Its is not found")
# Out:
# Its is not found

# %%
#list() constructor

# %%
name1="azar","mohamed","sheik"
list3=list(name1)
print(list3)
print(type(list3))
# Out:
# ['azar', 'mohamed', 'sheik']
# <class 'list'>

# %%
#Tuple Declaration
tup1=(10,20,30,40)
print(tup1)
print(type(tup1))
# Out:
# (10, 20, 30, 40)
# <class 'tuple'>

# %%
#Dictionary Declaration
dict1={101:"Azar",102:"mohamed"}
print(dict1)
print(type(dict1))
# Out:
# {101: 'Azar', 102: 'mohamed'}
# <class 'dict'>

# %%
[]-subscript
{}-set
()-tuples
{}--dict

# %%
list1
# Out:
# [100, 20, 30, 40]

# %%
list1.insert(0,200)
list1
# Out:
# [200, 100, 20, 30, 40]

# %%
#list1[0]=100

# %%
list1=[10,20,30,40]
print(list1)
# Out:
# [10, 20, 30, 40]

# %%
list1.append(50)
print(list1)
# Out:
# [10, 20, 30, 40, 50]

# %%
list1
# Out:
# [10, 20, 30, 40, 50]

# %%
list2=[100,200,300,400]
list1.extend(list2)
list1
# Out:
# [10, 20, 30, 40, 50, 100, 200, 300, 400, 100, 200, 300, 400]

# %%
list2.remove(100)
list2
# Out:
# [200, 300, 400]

# %%
list2.pop()
list2
# Out:
# [200, 300]

# %%
list2.pop(-1)
# Out:
# 300

# %%
list2
# Out:
# [200]

# %%
list1
# Out:
# [20, 50, 100, 200, 300, 400, 100, 200, 300]

# %%
del list1[0]
list1
# Out:
# [50, 100, 200, 300, 400, 100, 200, 300]

# %%
list1.pop()
# Out:
# 200

# %%
list1
# Out:
# [50, 100, 200, 300, 400, 100]

# %%
for x in list1:
    print(x)
# Out:
# 50
# 100
# 200
# 300
# 400
# 100

# %%
for i in range(len(list1)):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
while(i<len(list1)):
    print(list[i])
    i=i+1
# Out:
# list[5]

# %%
list1
# Out:
# [50, 100, 200, 300, 400, 100]

# %%
list3=['a1','a2','a3','a4']

# %%
newlist=[]
for i in list3:
    if 'a2' in i:
        newlist.append(i)
print(newlist)
# Out:
# ['a2']

# %%
print(newlist)
# Out:
# ['a2']

# %%
#Tuple concepts

# %%
tup1=(10,20,30,40)
print(tup1)
print(type(tup1))
# Out:
# (10, 20, 30, 40)
# <class 'tuple'>

# %%
tup1=(10,10,20,30,40,40)
print(tup1)
print(len(tup1))
# Out:
# (10, 10, 20, 30, 40, 40)
# 6

# %%
list1=[10,20,30,40]
list2=tuple(list1)
print(list2)
# Out:
# (10, 20, 30, 40)

# %%
tup1
# Out:
# (10, 10, 20, 30, 40, 40)

# %%
for i in tup1:
    print(i)
# Out:
# 10
# 10
# 20
# 30
# 40
# 40

# %%
if 11 in tup1:
    print("yes","found")
else:
    print("No","Not found")
# Out:
# No Not found

# %%
tup1[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 tup1[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup1
# Out:
# (10, 10, 20, 30, 40, 40)

# %%
tup1.remove(10)
tup1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tup1.remove(10)
#       2 tup1
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
y=list(tup1)
print(y)
y.remove(10)
print(y)
# Out:
# [10, 10, 20, 30, 40, 40]
# [10, 20, 30, 40, 40]

# %%
del tup1

# %%
tup1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 tup1
#
# NameError: name 'tup1' is not defined

# %%
tup1
# Out:
# (10, 20, 30, 40)

# %%
(a1,a2,a3,a4)=tup1

# %%
print(a1)
print(a2)
print(a3)
print(a4)
# Out:
# 10
# 20
# 30
# 40

# %%
tup2=(10,20,30,40)
(a1,a2,*a3)=tup2

# %%
print(a1)
print(a2)
print(a3)
# Out:
# 10
# 20
# [30, 40]

# %%
print(tup1+tup2)
# Out:
# (10, 20, 30, 40, 10, 20, 30, 40)

# %%
tup1*2
# Out:
# (10, 20, 30, 40, 10, 20, 30, 40)

# %%
tup1
# Out:
# (10, 20, 30, 40)

# %%
x=tup1.count(10)
x
# Out:
# 1

# %%
x1=tup1.index(30)
x1
# Out:
# 2

# %%
#Dictionary
dict1={"pid":1001,"pname":"apple","pprice":100}
print(dict1)
print(type(dict1))
# Out:
# {'pid': 1001, 'pname': 'apple', 'pprice': 100}
# <class 'dict'>

# %%
print(dict1["pid"])
print(dict1["pname"])
print(dict1.get("pid"))
# Out:
# 1001
# apple
# 1001

# %%
print(dict1.keys())
print(dict1.values())
print(dict1.items())
# Out:
# dict_keys(['pid', 'pname', 'pprice'])
# dict_values([1001, 'apple', 100])
# dict_items([('pid', 1001), ('pname', 'apple'), ('pprice', 100)])

# %%
dict1["pid"]="1004"
dict1
# Out:
# {'pid': '1004', 'pname': 'apple', 'pprice': 100}

# %%
dict1.update({"pid":1005})
dict1
# Out:
# {'pid': 1005, 'pname': 'apple', 'pprice': 100}

# %%
dict1.update({"age":33})
dict1
# Out:
# {'pid': 1006, 'pname': 'apple', 'pprice': 100, 'age': 33}

# %%
dict1.pop("pid")
dict1
# Out:
# {'pname': 'apple', 'pprice': 100, 'age': 33}

# %%
dict1.popitem()
# Out:
# ('age', 33)

# %%
dict2={101:"azar",102:"mohamed",103:"sheik"}
print(dict2)
# Out:
# {101: 'azar', 102: 'mohamed', 103: 'sheik'}

# %%
#delete dict
del dict2[101]

# %%
dict2
# Out:
# {102: 'mohamed', 103: 'sheik'}

# %%
dict2.clear()

# %%
dict2
# Out:
# {}

# %%
#Python Loop Dictionaries

# %%
dict2
# Out:
# {101: 'azar', 102: 'mohamed', 103: 'sheik'}

# %%
for i in dict2:
    print(i)
# Out:
# 101
# 102
# 103

# %%
for i in dict2.items():
    print(i)
# Out:
# (101, 'azar')
# (102, 'mohamed')
# (103, 'sheik')

# %%
for i in dict2.keys():
    print(i)
# Out:
# 101
# 102
# 103

# %%
#Copy Dictionaries
dict2
# Out:
# {101: 'azar', 102: 'mohamed', 103: 'sheik'}

# %%
my1=dict2.copy()
print(my1)
# Out:
# {101: 'azar', 102: 'mohamed', 103: 'sheik'}

# %%
my2=dict(dict2)
print(my2)
# Out:
# {101: 'azar', 102: 'mohamed', 103: 'sheik'}

# %%
#Nested dictionaries
dict3={
    "c1":{
    "name":"azar",
    "age":33
    },
    "c2":{
    "name":"mohamed",
    "age":34
    }
}

# %%
dict3
# Out:
# {'c1': {'name': 'azar', 'age': 33}, 'c2': {'name': 'mohamed', 'age': 34}}

# %%
dict3["c1"]
# Out:
# {'name': 'azar', 'age': 33}

# %%
dict3.keys()
# Out:
# dict_keys(['c1', 'c2'])
