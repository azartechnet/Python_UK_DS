# %%
a=100
print(a)
print(type(a))
# Out:
# 100
# <class 'int'>

# %%
name="azar"
print(name)
print(type(name))
# Out:
# azar
# <class 'str'>

# %%
avg=2.5
print(avg)
print(type(avg))
# Out:
# 2.5
# <class 'float'>

# %%
#RuntimeInput
p1=int(input("Enter the p1 value is::"))
p2=int(input("Enter the p2 value is::"))
print(p1,p2)
print(type(p1))
print(type(p2))
print("Your Result is::",p1*p2)
# Out:
# Enter the p1 value is::10
# Enter the p2 value is::20
# 10 20
# <class 'int'>
# <class 'int'>
# Your Result is:: 200

# %%
p1=input("Enter the p1 value is::")
p2=input("Enter the p2 value is::")
print(p1)
print(p2)
# Out:
# Enter the p1 value is::a1
# Enter the p2 value is::100
# a1
# 100

# %%
p1=int(input("Enter the p1 value:"))

p2=int(input("Enter the p2 value::"))

print("Add::",(p1+p2))

print("Sub::",(p1-p2))

print("Mul::",(p1*p2))

print("Division::",(p1/p2))

print("FloorDivision::",(p1//p2))

print("Module::",(p1%p2))
# Out:
# Enter the p1 value:10
# Enter the p2 value::20
# Add:: 30
# Sub:: -10
# Mul:: 200
# Division:: 0.5
# FloorDivision:: 0
# Module:: 10

# %%
print("lessthan::",(p1<p2))

print("Greaterthan::",(p2>p1))

print("Equal to::",(p1==p2))

print("Not Equal to::",(p1!=p2))

print("Greaterthan::",(p1>p2))
# Out:
# lessthan:: True
# Greaterthan:: True
# Equal to:: False
# Not Equal to:: True
# Greaterthan:: False

# %%
print("LogicalAND::",(p1<p2)and(p2>p1))
print("LogicalAND::",(p1>p2)and(p2>p1))
print("LogicalAND::",(p1>p2)and(p2==p1))
# Out:
# LogicalAND:: True
# LogicalAND:: False
# LogicalAND:: False

# %%
print("LogicalOR::",(p1>p2)or(p2>p1))
# Out:
# LogicalOR:: True

# %%
print("LogicalNOT::",not(p1>p2))
# Out:
# LogicalNOT:: True

# %%
a=2
b=2
#a+=2#a=a+2
a+=b
print(a)
# Out:
# 4

# %%
#if else

pid=int(input("Enter the pid is::"))
if(pid==1001):
    print("Pid is equal",pid)
else:
    print("Pid is not equal",pid)
# Out:
# Enter the pid is::1001
# Pid is equal 1001

# %%
p1=int(input("Enter the p1 value is::"))
if(p1%2==0):
    print("Its Even::",p1)
else:
    print("Its Odd::",p1)
# Out:
# Enter the p1 value is::5
# Its Odd:: 5

# %%
age=int(input("Enter the age is::"))
if(age>=60):
    sal=int(input("Enter the sal is::"))
    if(sal>=2000):
        bns=sal+500
        print("Your salary is::",bns)
    else:
        bns=sal+1000
        print("Your salary is::",bns)
else:
    print("Age is low")
# Out:
# Enter the age is::61
# Enter the sal is::1000
# Your salary is:: 2000

# %%
#for loops Concepts
for i in range(2,10,2):
    print("I value is::",i)
# Out:
# I value is:: 2
# I value is:: 4
# I value is:: 6
# I value is:: 8

# %%
for i in range(0,10,1):
    if(i%2==0):
        print("Even value is::",i)
    else:
        print("Odd value is::",i)
# Out:
# Even value is:: 0
# Odd value is:: 1
# Even value is:: 2
# Odd value is:: 3
# Even value is:: 4
# Odd value is:: 5
# Even value is:: 6
# Odd value is:: 7
# Even value is:: 8
# Odd value is:: 9

# %%
for i in range(0,2,1):
    for j in range(0,2,1):
        print("I value is::",i,"J value is::",j)
# Out:
# I value is:: 0 J value is:: 0
# I value is:: 0 J value is:: 1
# I value is:: 1 J value is:: 0
# I value is:: 1 J value is:: 1

# %%
i=0
n=int(input("Enter the n value is::"))
while(i<=n):
    print("I value is::",i)
    i=i+1
# Out:
# Enter the n value is::10
# I value is:: 0
# I value is:: 1
# I value is:: 2
# I value is:: 3
# I value is:: 4
# I value is:: 5
# I value is:: 6
# I value is:: 7
# I value is:: 8
# I value is:: 9
# I value is:: 10
